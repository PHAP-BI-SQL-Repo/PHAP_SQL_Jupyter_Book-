-- %% [markdown]
-- Enterprise Data Strategy disciplines:
--
-- Data Governance
--
-- Data Architecture
--
-- Data architects: are senior visionaries who translate business requirements into technology requirments and define data standards and principles.
--
-- Tasked with procedures around data storage, consumption, management, and integration with systems
--
-- Data Engineer:
--
-- Tasked with dealing with data and making it meaningful for others to consume.
--
-- Data Analyst:
--
-- Tasked with processing, visualizing, and reporting from data to improve the business
--
-- Data Modeling
--
--
--
-- Data Governance Policies:#####################
--
-- Corporate Glossary:
--
-- Industry terminology
--
-- Company terminology
--
-- Common metrics
--
-- Speak same language
--
-- Enterprise Data Dictionary
--
-- Mother of all data dictionaries
--
-- Describes data object metadata:
--
-- Name
--
-- Description
--
-- Domain \[data type\]
--
-- Example
--
-- Notes
--
-- Good place to tag for compliance
--
-- Naming Conventions
--
-- Rules for data object names
--
-- Abbreviations
--
-- Caps
--
-- Underscores
--
-- camelCase
--
-- Pascal case
--
-- Information Security
--
-- Compliance
--
-- PCI/PCI-DSS
--
-- Sarbanes-Oxley
--
-- HIPAA
--
-- InfoSec (CyberSec)
--
-- Change Management
--
-- Documentation
--
-- Approval Process
--
-- With existing corporate or IT Governance
--
-- Data Project Management
--
-- Facilitates the initial meeting
--
-- Occasionally manage data projects
--
-- Roles in a Data Governance Program:
--
-- CDO \[should be a VP\]
--
-- Data Governance Director
--
-- Data Stewards \[stakeholders, should be business, nothing change without his approval\]
--
-- Subject Matter Experts \[SME\] \[like someone from cybersecurity or DB admin, anyone who know about something\]
--
-- Enterprise Information Architect
--
-- Data Modeler
--
-- Establishing a Data Governance Program:
--
-- Get executive sponsorship
--
-- Obtain and learn to use modeling software
--
-- ER Studio, ERWin
--
-- Open Source:
--
-- ER One, Open ModelSphere
--
-- Framework and/or Methodology
--
-- ID your data stewards and SMEs
--
-- Get commiments
--
-- Establish a data governance council:
--
-- Policy and inforcement
--
-- Enterprise glossary
--
-- Enterprise data model
--
-- Naming conventions for everything
--
-- Change management
--
-- Insert yourself into "stand-ups"
--
-- stay firm and be tenacious
--
-- Create a CR, change request form
--
-- ask the requester to attend the meeting
--
-- system outages
--
-- Risks to other systems
--
-- communications to users
--
--
--
-- Enterprise Data Architecture:###############
--
-- Data: Facts are attributes used to describe an entity or event
--
-- Information: Data is combined with context to describe a subject
--
-- Knowledge: Once that information is consumed, it becomes knowledge
--
-- Wisdom: with experience, knowledge becomes wisdom
--
-- TOGAF:
--
-- The Open Group Architecture Framework
--
-- Information Architecture = Data Architecture
--
-- TOGAF Four Pillars:
--
-- Data Architecture : Data lifecycle and modeling
--
-- Business Architecture : Models business requirements
--
-- Application Architecture: application logic and SDLC
--
-- Technology Architecture : Infrastructure model
--
-- Blockchain-A distributed ledger:
--
-- a transaction is encrypted and submitted
--
-- The submission is a representation called a block
--
-- The block is broadcast to the network
--
-- A node picks up the block to validate the transaction
--
-- it is again broadcast to the network for consenus
--
-- When enough nodes have validated the transaction, it is added to a the blockchain
--
-- The block gets added to the chain
--
-- Which is a type of ledger where it will remain forever
--
-- Confirmation transaction completed
--
-- Types of data:
--
-- Master: main data entity
--
-- Transaction: and thing happen between two master data
--
-- Lookup: descripes the codes and IDs
--
-- Metadata: describe table structures
--
--
--
-- Enterprise Data Model:
--
-- Logical Model Physical Model
--
-- Entity Table
--
-- Attribute Column
--
-- Row Record
--
-- Relationships Primary/Foreign Keys
--
-- Why we do data modeling:
--
-- Organize and define data
--
-- Common definitions and standards
--
-- Document business processes
--
-- Forward engineering
--
-- Managing and Working with data
--
-- What database administrator is,
--
-- The DBA and WHat they do
--
-- Selecting database servers
--
-- connection to the network, storage and application
--
-- Run and maintain backups of the database
--
-- Run occasional database restore tests
--
-- Automate maintenance tasks and other scheduled jobs
--
-- Manage database user and group accounts
--
-- secure the data
--
-- Monitor for performance and troubleshoots issues
--
-- Maintaining table indexing
--
-- suggesting changes to the database schema
--
-- Database development and DAO \[Data Access Objects\]
--
-- Embeded code vs. stored procedures
--
-- Data quality through data governance
--
-- Naming conventions
--
-- Data types
--
-- Lineage is documented
--
-- data profiling and scoring
--
-- More than jus NULL values
--
-- Gathering statistics about data values
--
-- Know your data
--
-- Compliance auditing
--
-- HIPPA
--
-- Sarbanes-Oxley
--
-- P||-Personally identifiable information
--
-- PCI-DSS
--
-- Payment card industry data security standard
--
-- Database-access
--
-- Failed login attempts
--
-- Principle of least privilege
--
-- Change management records
--
-- Subjected data
--
-- Who has access
--
-- How its secured
--
-- Where its stored
--
-- Retention
--
-- Data integration developers and ETL \[Data Munging\]
--
-- ETL Tools:
--
-- Informatica
--
-- SyncSort DMX and DMX-h \[h=Hadoop\]
--
-- Microsoft SSIS
--
-- IBM Infosphere Datastage
--
-- Talend
--
-- Pentaho Data Integration
--
-- Jasper
--
-- Apache Camel
--
-- Getting Value from Data
--
-- The f \[V\]s ofBig Data:
--
-- Volume: alot of data \> 1 TB
--
-- Variety: structured, unstructured
--
-- Velocity: Always more coming
--
-- Variability: Data from disparate sources
--
-- Veracity: Potential data quality issues
--
-- Data engineering (Big Data)
--
-- More than ETL development
--
-- Data munging or wrangling
--
-- Data pipelines/connecting pipelines
--
-- Build proof-of-concepts \[POC\] fast
--
-- Fail fast, fail often
--
-- Productionalize
--
-- DE Languages: R, Python, SAS, Java, SQL, Scala, Go, Julia
--
-- DE Systems: Vertica (or another columnar database), SAS Enviroment, R Studio Server, Anaconda Enterprise Server (python), Hadoop
--
-- Tidy Data:
--
-- Duplicates
--
-- Formats
--
-- Business intelligence \[BI\]
--
-- The BI developer role:
--
-- Design report layout
--
-- Connects to data sources
--
-- BI tools:
--
-- SSRS, Business Objects BO, Tableau
--
-- Enterprise Content Management:
--
-- Joombla
--
-- Plone
--
-- Magento
--
-- Wiki
--
-- Exploratory data analytics \[EDA\] Subject Data Matters \[SMEs\]
--
-- Statistical data analytics
--
-- The science part of data science:
--
-- Scientific method
--
-- Sampling
--
-- Hypotheses test
--
-- Significance?
--
-- Who is a data scientests:
--
-- Statistician
--
-- Data Engineer
--
-- Business analyst
--
-- Graphic designer
--
-- Predictive modeling:
--
-- Forecasting from patterns in existing data
--
-- Choosing variables from a tidy dataset
--
-- Machine language \[ML\] algorithms
--
-- Supervised
--
-- Train/Test datasets
--
-- Decision tress
--
-- Naive Bayes classification
--
-- Regression
--
-- Support Vector Machines SVM
--
-- Unsupervised
--
-- No training
--
-- Anomaly detection
--
-- Clustering
--
-- K-Means clustering
--
-- K-NN Nearest Neighbors
--
-- Semi-Supervised Learning
--
-- Reinforced
--
-- Deep Learning
--
-- Predictive Modeling Solutions:
--
-- SAS
--
-- IBM's SPSS
--
-- Python libraries
--
-- R Libraries
--
-- Tensor flaw
--
-- Knowledge discovery and data mining \[KDD\]
--
-- SUMMARY
--
-- Exploratory data analysis:
--
-- Discover value
--
-- Statistical data analysis:
--
-- Understand the nature
--
-- Provide evidence
--
-- Predictive modeling:
--
-- To make educated business decsions
--
-- Data visualization \[Data-viz\]
--
-- Telling a story
--
-- Infographics: Canva, Venngage, Pikochart
--
-- Animated graphics
--
-- Disciplines of EDM \[\]
--
-- Data Governance
--
-- Data Architecture
--
-- Data Modeling
--
-- Database and DW administratorData Development
--
-- Data Integration ETL
--
-- Data Engineering
--
-- Business Intelligence
--
-- Exploratory Data Analysis
--
-- Statistical Data Analysis
--
-- Predictive Modeling
--
-- Data Visualizations
